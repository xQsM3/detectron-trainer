# %%
# %run -i 'PlotTogether.py' ./output
# Out:
# [{'bbox/AP': 0.0, 'bbox/AP50': 0.0, 'bbox/AP75': 0.0, 'bbox/APl': nan, 'bbox/APm': nan, 'bbox/APs': 0.0, 'data_time': 0.0012238695053383708, 'eta_seconds': 10424.999181712337, 'iteration': 19, 'loss_box_reg': 0.08753657341003418, 'loss_cls': 0.08595714718103409, 'lr': 1.4985749999999999e-06, 'num_pos_anchors': 4.0, 'time': 0.10427084598632064, 'timetest': 12.0, 'total_loss': 0.17853714525699615, 'validation_loss': 1.7325483940076083}, {'bbox/AP': 0.0, 'bbox/AP50': 0.0, 'bbox/AP75': 0.0, 'bbox/APl': nan, 'bbox/APm': nan, 'bbox/APs': 0.0, 'data_time': 0.0012970115058124065, 'eta_seconds': 10304.101509599132, 'iteration': 39, 'loss_box_reg': 0.47985441982746124, 'loss_cls': 0.4540605992078781, 'lr': 2.9970749999999996e-06, 'num_pos_anchors': 4.0, 'time': 0.100101886986522, 'timetest': 12.0, 'total_loss': 0.923136368393898, 'validation_loss': 2.675677073188126}, {'bbox/AP': 0.0, 'bbox/AP50': 0.0, 'bbox/AP75': 0.0, 'bbox/APl': nan, 'bbox/APm': nan, 'bbox/APs': 0.0, 'data_time': 0.00123754
# ...

# %%
# %run -i 'PlotTogether.py' /home/linx123-rtx/multi-ants-tracking/Detectron2_training/output_retina101_BS16_LR0.00005_0.000005_gamma5/output

# %%
# %run -i 'PlotTogether.py' /home/linx123-rtx/multi-ants-tracking/Detectron2_training/output_retina101_BS16_LR0.00005_0.000005_gamma5_anchor0.5size/output

# %%
# %run -i 'PlotTogether.py' /home/linx123-rtx/multi-ants-tracking/Detectron2_training/output_retina101_BS16_LR0.00075_0.0000075/output
